# %%
import json
import pandas as pd
import requests
import os
import csv
import sqlite3

# %%
#API REQUEST

# API endpoint for disney characters
url = "https://api.disneyapi.dev/character"

# Make the GET request
response = requests.get(url)
data = response.json()

# Check if the request was successful
# Check the status code
if response.status_code == 200:
    print("API request successful!")
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# API request successful!

# %%
# Creating function to put all the pages together
def getData(url): # (Fetch)
  page = 1
  totalRecords = 0
  allData = []

  while page <= 149:
    response = requests.get(url, params={'page': page})
    data = response.json()

    allData.extend(data['data'])

    # Count all the records on the current page
    totalRecords += len(data['data'])
    page += 1

  return allData, totalRecords

allData, totalRecords = getData(url)

# %%
# Counting the number of columns and records (Pre)

numColumns = len(allData[0].keys())
print(f"Number of columns before modification: {numColumns}")

print(f"Number of records before modification: {totalRecords}")
# Out:
# Number of columns before modification: 15
# Number of records before modification: 7438

# %%
# Titles of the columns
print(allData[0])
# Out:
# {'_id': 112, 'films': ['Hercules (film)'], 'shortFilms': [], 'tvShows': ['Hercules (TV series)'], 'videoGames': ['Kingdom Hearts III'], 'parkAttractions': [], 'allies': [], 'enemies': [], 'sourceUrl': 'https://disney.fandom.com/wiki/Achilles_(Hercules)', 'name': 'Achilles', 'imageUrl': 'https://static.wikia.nocookie.net/disney/images/d/d3/Vlcsnap-2015-05-06-23h04m15s601.png', 'createdAt': '2021-04-12T01:31:30.547Z', 'updatedAt': '2021-12-20T20:39:18.033Z', 'url': 'https://api.disneyapi.dev/characters/112', '__v': 0}

# %%
# Removing columns (Modify)
columsRemoved = ['imageUrl', 'videoGames','shortFilms', 'createdAt']
for record in allData:
  for column in columsRemoved:
      if column in record:
          del record[column]

# %%
# Showing the data to confirm that the columns have been removed (Post)
print(allData[0])
# Out:
# {'_id': 112, 'films': ['Hercules (film)'], 'tvShows': ['Hercules (TV series)'], 'parkAttractions': [], 'allies': [], 'enemies': [], 'sourceUrl': 'https://disney.fandom.com/wiki/Achilles_(Hercules)', 'name': 'Achilles', 'updatedAt': '2021-12-20T20:39:18.033Z', 'url': 'https://api.disneyapi.dev/characters/112', '__v': 0}

# %%
# Asking user input for converting the JSON file
print("Would you like to convert the JSON file to a CSV file then SQL file or a SQL file directly?")
question = input("Please enter either directSQL or CSV: ")

if question == 'CSV':
  df = pd.DataFrame(allData)
  df.to_csv('output.csv', index=False)

  df = pd.read_csv('output.csv')


  num_records_after = len(df)
  num_columns_after = len(df.columns)
  print(f"Number of records after conversion: {num_records_after}")
  print(f"Number of columns after conversion: {num_columns_after}")

  connect = sqlite3.connect('output.db')
  df.to_sql('disney_characters', connect, if_exists='replace', index=False) # (Store)



  connect.close()
  print("CSV file created and SQL file created")

elif question == 'directSQL':
  df = pd.DataFrame(data['data'])
  df = df.map(lambda x: str(x) if isinstance(x, (list, dict)) else x)

  num_records_after = len(df)
  num_columns_after = len(df.columns)
  print(f"Number of records after conversion: {num_records_after}")
  print(f"Number of columns after conversion: {num_columns_after}")

  connect = sqlite3.connect('output.db')

  df.to_sql('output', connect, if_exists='replace', index=False)

  connect.close()
  print("SQL file created")

else:
  print("Please enter either directSQL or CSV exactly as they appear")
# Out:
# Would you like to convert the JSON file to a CSV file then SQL file or a SQL file directly?
# Please enter either directSQL or CSV: CSV
# Number of records after conversion: 7438
# Number of columns after conversion: 12
# CSV file created and SQL file created

# %%
#CSV FILE - Top 100 Healthiest Foods in the World; 9 columns x 99 rows

file = 'Top 100 Healthiest Food in the World.csv'
# Load Data from Top 100 Healthiest Foods
healthyFoodsDF = pd.read_csv('Top 100 Healthiest Food in the World.csv', sep=',')

# Display the first few foods
print("Healthiest Foods in the World:")
display(healthyFoodsDF.head())

# initializing the titles and rows list
columns = []
rows = []

# reading csv file
with open(file, 'r') as csvfile:
    # creating a csv reader object
    csvreader = csv.reader(csvfile)

    # extracting columns
    columns = next(csvreader)

    # extracting each data row one by one
    for row in csvreader:
        rows.append(row)

    # get total number of rows
    print("Total number of rows: %d" % (csvreader.line_num))

# printing the field names
print("Number of Columns:", len(columns))
# Out:
# Healthiest Foods in the World:
#           Food   Nutrition Value (per 100g)        Quantity  \
# 0         Kale     High in Vitamins A, C, K  1 cup, chopped
# 1  Blueberries         High in Antioxidants           1 cup
# 2       Salmon  Rich in Omega-3 Fatty Acids            3 oz
# 3       Garlic             Contains Allicin         1 clove
# 4      Spinach      High in Iron and Folate      1 cup, raw
#
#        Originated From  Calories  Protein (g)  Fiber (g)  Vitamin C (mg)  \
# 0       Ancient Greece        49          4.3        3.6            93.4
# 1        North America        84          1.1        3.6            14.4
# 2  North Pacific Ocean       208         22.1        0.0             0.0
# 3         Central Asia         4          0.2        0.1             0.9
# 4       Ancient Persia        23          2.9        2.2            28.1
#
#    Antioxidant Score
# 0               1770
# 1               9621
# 2                689
# 3               5708
# 4               1515
# Total number of rows: 99
# Number of Columns: 9

# %%
# Dropping the Antioxidant Score
healthyFoodsDF.drop('Antioxidant Score', axis=1, inplace=True)

# Display the first few foods
print("Healthiest Foods in the World:")
display(healthyFoodsDF.head())
# Out:
# Healthiest Foods in the World:
#           Food   Nutrition Value (per 100g)        Quantity  \
# 0         Kale     High in Vitamins A, C, K  1 cup, chopped
# 1  Blueberries         High in Antioxidants           1 cup
# 2       Salmon  Rich in Omega-3 Fatty Acids            3 oz
# 3       Garlic             Contains Allicin         1 clove
# 4      Spinach      High in Iron and Folate      1 cup, raw
#
#        Originated From  Calories  Protein (g)  Fiber (g)  Vitamin C (mg)
# 0       Ancient Greece        49          4.3        3.6            93.4
# 1        North America        84          1.1        3.6            14.4
# 2  North Pacific Ocean       208         22.1        0.0             0.0
# 3         Central Asia         4          0.2        0.1             0.9
# 4       Ancient Persia        23          2.9        2.2            28.1

# %%
# Changing dataframe to include only top 50 foods
healthyFoodsDF = healthyFoodsDF[:-47]

# Display the first few foods
print("Top 50 Healthiest Foods in the World:")
display(healthyFoodsDF)
# Out:
# Top 50 Healthiest Foods in the World:
#                 Food           Nutrition Value (per 100g)           Quantity  \
# 0               Kale             High in Vitamins A, C, K     1 cup, chopped
# 1        Blueberries                 High in Antioxidants              1 cup
# 2             Salmon          Rich in Omega-3 Fatty Acids               3 oz
# 3             Garlic                     Contains Allicin            1 clove
# 4            Spinach              High in Iron and Folate         1 cup, raw
# 5            Almonds             Good Source of Vitamin E     1 oz (23 nuts)
# 6           Broccoli              High in Vitamin C and K     1 cup, chopped
# 7            Avocado                 Rich in Healthy Fats           1 medium
# 8             Quinoa              Complete Protein Source      1 cup, cooked
# 9            Lentils            High in Protein and Fiber      1 cup, cooked
# 10      Sweet Potato                Rich in Beta-Carotene           1 medium
# 11         Green Tea                    High in Catechins      1 cup, brewed
# 12          Turmeric                    Contains Curcumin      1 tsp, ground
# 13              Eggs              Complete Protein Source            1 large
# 14        Chia Seeds            High in Omega-3 and Fiber               1 oz
# 15      Greek Yogurt       High in Protein and Probiotics               6 oz
# 16       Pomegranate                 Rich in Antioxidants           1 medium
# 17           Walnuts               Good Source of Omega-3   1 oz (14 halves)
# 18            Ginger         Anti-inflammatory Properties     1 tbsp, grated
# 19         Olive Oil         Rich in Monounsaturated Fats             1 tbsp
# 20             Beets                     High in Nitrates         1 cup, raw
# 21          Sardines        Rich in Omega-3 and Vitamin D    3.75 oz, canned
# 22         Mushrooms              Good Source of Selenium         1 cup, raw
# 23          Tomatoes                     High in Lycopene           1 medium
# 24              Oats                  Rich in Beta-Glucan      1 cup, cooked
# 25         Flaxseeds                      High in Lignans     1 tbsp, ground
# 26  Brussels Sprouts                    High in Vitamin K      1 cup, cooked
# 27     Pumpkin Seeds                    Rich in Magnesium               1 oz
# 28       Black Beans            High in Fiber and Protein      1 cup, cooked
# 29        Green Peas             Good Source of Vitamin K      1 cup, cooked
# 30         Asparagus                       High in Folate      1 cup, cooked
# 31      Blackberries                 Rich in Antioxidants              1 cup
# 32         Wild Rice            High in Protein and Fiber      1 cup, cooked
# 33           Seaweed                       Rich in Iodine      1 sheet, nori
# 34       Cauliflower   Low in Calories, High in Nutrients         1 cup, raw
# 35       Coconut Oil  Contains Medium-Chain Triglycerides             1 tbsp
# 36  Red Bell Peppers                    High in Vitamin C     1 cup, chopped
# 37        Watercress                    High in Vitamin K     1 cup, chopped
# 38        Artichokes                        High in Fiber           1 medium
# 39          Cherries                   Contains Melatonin   1 cup, with pits
# 40             Mango                    High in Vitamin A      1 cup, sliced
# 41        Pistachios            Good Source of Vitamin B6  1 oz (49 kernels)
# 42              Kiwi                    High in Vitamin C           1 medium
# 43           Oranges                    Rich in Vitamin C           1 medium
# 44         Chickpeas            High in Protein and Fiber      1 cup, cooked
# 45            Papaya               Contains Papain Enzyme       1 cup, cubed
# 46           Cabbage   Low in Calories, High in Vitamin K     1 cup, chopped
# 47       Brazil Nuts                     High in Selenium    1 oz (6-8 nuts)
# 48        Cantaloupe                    High in Vitamin A       1 cup, cubed
# 49           Edamame   Good Source of Plant-Based Protein     1 cup, shelled
# 50            Apples                    Rich in Quercetin           1 medium
#
#           Originated From  Calories  Protein (g)  Fiber (g)  Vitamin C (mg)
# 0          Ancient Greece        49          4.3        3.6            93.4
# 1           North America        84          1.1        3.6            14.4
# 2     North Pacific Ocean       208         22.1        0.0             0.0
# 3            Central Asia         4          0.2        0.1             0.9
# 4          Ancient Persia        23          2.9        2.2            28.1
# 5             Middle East       164          6.0        3.5             0.0
# 6                   Italy        31          2.5        2.4            81.2
# 7         Central America       320          4.0       13.5            10.0
# 8           South America       222          8.1        5.2             0.0
# 9             Middle East       230         17.9       15.6             2.1
# 10  Central/South America       103          2.3        3.8            22.3
# 11                  China         2          0.5        0.0             0.0
# 12                  India         9          0.3        0.7             0.5
# 13              Worldwide        72          6.3        0.0             0.0
# 14        Central America       138          4.7       10.6             0.1
# 15                 Greece       100         17.3        0.0             0.0
# 16            Middle East       234          4.7       11.3            28.8
# 17         Ancient Persia       185          4.3        1.9             0.4
# 18         Southeast Asia         4          0.1        0.2             0.7
# 19   Mediterranean Region       119          0.0        0.0             0.0
# 20   Mediterranean Region        58          2.2        3.8             6.7
# 21      Mediterranean Sea       191         22.7        0.0             0.0
# 22              Worldwide        15          2.2        1.0             2.8
# 23          South America        22          1.1        1.5            15.6
# 24                 Europe       166          5.9        4.0             0.0
# 25            Middle East        37          1.3        1.9             0.1
# 26           Ancient Rome        56          4.0        4.1            96.7
# 27          North America       151          7.0        1.7             0.5
# 28          South America       227         15.2       15.0             0.0
# 29   Mediterranean Region       134          8.6        8.8            13.7
# 30  Eastern Mediterranean        27          2.9        2.8            12.3
# 31              Worldwide        62          2.0        7.6            30.2
# 32          North America       166          6.5        3.0             0.0
# 33                  Japan         1          0.1        0.3             0.7
# 34                 Cyprus        25          2.0        2.5            48.2
# 35         Southeast Asia       121          0.0        0.0             0.0
# 36  Central/South America        46          1.5        3.1           190.0
# 37                 Europe         4          0.8        0.2            14.6
# 38   Mediterranean Region        60          4.2        6.9             8.9
# 39             Asia Minor        97          1.6        3.2            10.8
# 40             South Asia        99          1.4        2.6            60.1
# 41           Central Asia       159          5.7        3.0             0.7
# 42                  China        42          0.8        2.1            64.0
# 43         Southeast Asia        62          1.2        3.1            69.7
# 44            Middle East       269         14.5       12.5             2.1
# 45        Central America        62          0.9        2.5           168.0
# 46                 Europe        22          1.1        2.2            36.6
# 47          South America       186          4.1        2.1             0.2
# 48     Middle East/Africa        54          1.3        1.4            59.4
# 49              East Asia       188         18.4        8.0             6.1
# 50           Central Asia        95          0.5        4.4             8.4

# %%
# Addtional column: My personal rating of the taste of each food on a scale from 1-10
rating = [5, 7, 8, 10, 5, 6, 7, 10, 4, 5, 4, 6, 4, 9, 5, 8, 7, 6, 5, 5, 1, 2, 5, 7, 7, 5, 4, 4, 6, 6, 6, 8, 10, 9, 7, 3, 6, 4, 3, 9, 10, 7, 7, 7, 6, 6, 5, 5, 4, 8, 7]
healthyFoodsDF.insert(8, "Teagans Taste Rating", rating)

# Display the first few foods
print("Top 50 Healthiest Foods in the World:")
display(healthyFoodsDF.head())

# disply number of rows in altered databse
print("Number of Rows After Alteration:", len(healthyFoodsDF))

# display number of columns in altered databse
print("Number of Columns After Alteration:", len(healthyFoodsDF.columns))
# Out:
# Top 50 Healthiest Foods in the World:
#           Food   Nutrition Value (per 100g)        Quantity  \
# 0         Kale     High in Vitamins A, C, K  1 cup, chopped
# 1  Blueberries         High in Antioxidants           1 cup
# 2       Salmon  Rich in Omega-3 Fatty Acids            3 oz
# 3       Garlic             Contains Allicin         1 clove
# 4      Spinach      High in Iron and Folate      1 cup, raw
#
#        Originated From  Calories  Protein (g)  Fiber (g)  Vitamin C (mg)  \
# 0       Ancient Greece        49          4.3        3.6            93.4
# 1        North America        84          1.1        3.6            14.4
# 2  North Pacific Ocean       208         22.1        0.0             0.0
# 3         Central Asia         4          0.2        0.1             0.9
# 4       Ancient Persia        23          2.9        2.2            28.1
#
#    Teagans Taste Rating
# 0                     5
# 1                     7
# 2                     8
# 3                    10
# 4                     5
# Number of Rows After Alteration: 51
# Number of Columns After Alteration: 9

# %%
#CSV Conversion (Convert)
askForm = print('Would you like to convert the CSV to a SQL file directly or to JSON file then SQL file?')
form = input('Please enter either direct or JSON: ')


#Convert CSV to JSON
if form == 'JSON':
  healthyFoodsDF.to_json('Top 100 Healthiest Foods in the World.json')
  healthyFoodsDF.to_sql('Top 100 Healthiest Foods in the World.db', con=sqlite3.connect('Top 100 Healthiest Foods in the World.db'))
  print('CSV converted to SQL')
#Convert CSV to SQL
elif form == 'direct':
  healthyFoodsDF.to_sql('Top 100 Healthiest Foods in the World.db', con=sqlite3.connect('Top 100 Healthiest Foods in the World.db'))
  print('CSV converted to SQL')
#Error mitigation if user enters something else
else:
  print('Please enter either direct or JSON exactly as they appear')
# Out:
# Would you like to convert the CSV to a SQL file directly or to JSON file then SQL file?
# Please enter either direct or JSON: direct
# CSV converted to SQL
